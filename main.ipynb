# %%
import cv2
import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
import numpy as np
from pygame import mixer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\S U B H A M\Downloads\Compressed\Driver-Drowsiness-Detection-using-Deep-Learning-main\Driver-Drowsiness-Detection-using-Deep-Learning-main\main.ipynb Cell 1 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import tensorflow as tf
#       <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> from tensorflow import keras
# ----> <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> from keras.models import load_model
#       <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a> from pygame import mixer
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\__init__.py:21, in <module>
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\models\__init__.py:18, in <module>
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\engine\functional.py:27, in <module>
#      24 import tensorflow.compat.v2 as tf
#      26 from keras import backend
# ---> 27 from keras.dtensor import layout_map as layout_map_lib
#      28 from keras.engine import base_layer
#      29 from keras.engine import base_layer_utils
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\dtensor\layout_map.py:25, in <module>
#      22 import tensorflow.compat.v2 as tf
#      24 from keras.dtensor import dtensor_api as dtensor
# ---> 25 from keras.dtensor import lazy_variable
#      26 from keras.dtensor import utils
#      27 from keras.engine import base_layer
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\dtensor\lazy_variable.py:26, in <module>
#      24 from tensorflow.python.ops import resource_variable_ops
#      25 from tensorflow.python.ops import variable_scope
# ---> 26 from tensorflow.python.trackable import base as trackable
#      27 from tensorflow.python.util import compat
#      28 from tensorflow.python.util import tf_contextlib
#
# ModuleNotFoundError: No module named 'tensorflow.python.trackable'

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
model = load_model(r"C:\Users\S U B H A M\Downloads\Compressed\Driver-Drowsiness-Detection-using-Deep-Learning-main\Driver-Drowsiness-Detection-using-Deep-Learning-main\models\model1.h5")

# %%
mixer.init()
sound= mixer.Sound(r"C:\Users\S U B H A M\Downloads\Compressed\Driver-Drowsiness-Detection-using-Deep-Learning-main\Driver-Drowsiness-Detection-using-Deep-Learning-main\alarm.wav")
cap = cv2.VideoCapture(0)
Score = 0
while True:
    ret, frame = cap.read()
    height,width = frame.shape[0:2]
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces= face_cascade.detectMultiScale(gray, scaleFactor= 1.2, minNeighbors=3)
    eyes= eye_cascade.detectMultiScale(gray, scaleFactor= 1.1, minNeighbors=1)
    
    cv2.rectangle(frame, (0,height-50),(200,height),(0,0,0),thickness=cv2.FILLED)
    
    for (x,y,w,h) in faces:
        cv2.rectangle(frame,pt1=(x,y),pt2=(x+w,y+h), color= (255,0,0), thickness=3 )
        
    for (ex,ey,ew,eh) in eyes:
        #cv2.rectangle(frame,pt1=(ex,ey),pt2=(ex+ew,ey+eh), color= (255,0,0), thickness=3 )
        
       # preprocessing steps
        eye= frame[ey:ey+eh,ex:ex+ew]
        eye= cv2.resize(eye,(80,80))
        eye= eye/255
        eye= eye.reshape(80,80,3)
        eye= np.expand_dims(eye,axis=0)
        # preprocessing is done now model prediction
        prediction = model.predict(eye)
        print(prediction)
        # if eyes are closed
        if prediction[0][0]>0.50:
            cv2.putText(frame,'closed',(10,height-20),fontFace=cv2.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv2.LINE_AA)
            cv2.putText(frame,'Score'+str(Score),(100,height-20),fontFace=cv2.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv2.LINE_AA)
            Score=Score+1
            if(Score>10):
                try:
                    sound.play()
                except:
                    pass
            
        # if eyes are open
        elif prediction[0][1]>0.90:
            cv2.putText(frame,'open',(10,height-20),fontFace=cv2.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv2.LINE_AA)      
            cv2.putText(frame,'Score'+str(Score),(100,height-20),fontFace=cv2.FONT_HERSHEY_COMPLEX_SMALL,fontScale=1,color=(255,255,255),
                       thickness=1,lineType=cv2.LINE_AA)
            Score = Score-1
            if (Score<0):
                Score=0
            
        
    cv2.imshow('frame',frame)
    if cv2.waitKey(33) & 0xFF==ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] -
-01]]
# 1/1 [==============================] - 0s 52ms/step
# [[0.72542864 0.2745714 ]]
# 1/1 [==============================] - 0s 54ms/step
# [[0.20637506 0.793625  ]]
# 1/1 [==============================] - 0s 53ms/step
# [[0.00355907 0.99644095]]
# 1/1 [==============================] - 0s 52ms/step
# [[0.00354014 0.9964599 ]]
# 1/1 [==============================] - 0s 51ms/step
# [[1.877353e-04 9.998123e-01]]
# 1/1 [==============================] - 0s 52ms/step
# [[0.19344394 0.80655605]]
# 1/1 [==============================] - 0s 53ms/step
# [[4.8594084e-05 9.9995136e-01]]
# 1/1 [==============================] - 0s 52ms/step
# [[0.00994929 0.99005073]]
# 1/1 [==============================] - 0s 54ms/step
# [[0.49234825 0.50765175]]
# 1/1 [==============================] - 0s 56ms/step
# [[8.2788269e-05 9.9991715e-01]]
# 1/1 [==============================] - 0s 52ms/step
# [[1.8873536e-04 9.9981123e-01]]
# 1/1 [==============================] - 0s 56ms/step
# [[0.01271265 0.9872873 ]]
# 1/1 [==============================] - 0s 51ms/step
# [[0.50738937 0.49261054]]
# 1/1 [==============================] - 0s 54ms/step
# [[0.01134668 0.98865336]]
# 1/1 [==============================] - 0s 53ms/step
# [[0.3813534 0.6186466]]
# 1/1 [==============================] - 0s 53ms/step
# [[0.00344247 0.9965576 ]]
# 1/1 [==============================] - 0s 58ms/step
# [[0.45551723 0.5444827 ]]
# 1/1 [==============================] - 0s 55ms/step
# [[2.4459105e-05 9.9997556e-01]]
# 1/1 [==============================] - 0s 55ms/step
# [[1.7435419e-06 9.9999821e-01]]
# 1/1 [==============================] - 0s 54ms/step
# [[0.5431897  0.45681024]]
# 1/1 [==============================] - 0s 56ms/step
# [[0.06404705 0.9359529 ]]
# 1/1 [==============================] - 0s 56ms/step
# [[0.00951647 0.9904835 ]]
# 1/1 [==============================] - 0s 53ms/step
# [[7.2160986e-04 9.9927837e-01]]
# 1/1 [==============================] - 0s 54ms/step
# [[0.8961969  0.10380314]]
# 1/1 [==============================] - 0s 52ms/step
# [[0.00545486 0.9945451 ]]
# 1/1 [==============================] - 0s 54ms/step
# [[8.891565e-04 9.991109e-01]]
# 1/1 [==============================] - 0s 54ms/step
# [[1.5414482e-05 9.9998462e-01]]
# 1/1 [==============================] - 0s 55ms/step
# [[0.17958423 0.8204158 ]]
# 1/1 [==============================] - 0s 56ms/step
# [[0.9875551  0.01244495]]
# 1/1 [==============================] - 0s 59ms/step
# [[0.2286755 0.7713246]]
# 1/1 [==============================] - 0s 57ms/step
# [[0.9920197  0.00798033]]
# 1/1 [==============================] - 0s 57ms/step
# [[0.25046888 0.7495311 ]]
# 1/1 [==============================] - 0s 59ms/step
# [[4.1769704e-04 9.9958235e-01]]
# 1/1 [==============================] - 0s 55ms/step
# [[0.19370922 0.80629075]]
# 1/1 [==============================] - 0s 53ms/step
# [[0.46557745 0.5344225 ]]
# 1/1 [==============================] - 0s 53ms/step
# [[0.00918065 0.9908194 ]]
# 1/1 [==============================] - 0s 64ms/step
# [[0.01373264 0.9862673 ]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\S U B H A M\Downloads\Compressed\Driver-Drowsiness-Detection-using-Deep-Learning-main\Driver-Drowsiness-Detection-using-Deep-Learning-main\main.ipynb Cell 4 in <cell line: 5>()
#      <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W3sZmlsZQ%3D%3D?line=24'>25</a> eye= np.expand_dims(eye,axis=0)
#      <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W3sZmlsZQ%3D%3D?line=25'>26</a> # preprocessing is done now model prediction
# ---> <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W3sZmlsZQ%3D%3D?line=26'>27</a> prediction = model.predict(eye)
#      <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W3sZmlsZQ%3D%3D?line=27'>28</a> print(prediction)
#      <a href='vscode-notebook-cell:/c%3A/Users/S%20U%20B%20H%20A%20M/Downloads/Compressed/Driver-Drowsiness-Detection-using-Deep-Learning-main/Driver-Drowsiness-Detection-using-Deep-Learning-main/main.ipynb#W3sZmlsZQ%3D%3D?line=28'>29</a> # if eyes are closed
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\engine\training.py:2002, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1995   except ValueError:
#    1996     warnings.warn(
#    1997         'Using Model.predict with MultiWorkerMirroredStrategy or '
#    1998         'TPUStrategy and AutoShardPolicy.FILE might lead to out-of-order '
#    1999         'result. Consider setting it to AutoShardPolicy.DATA.',
#    2000         stacklevel=2)
# -> 2002 data_handler = data_adapter.get_data_handler(
#    2003     x=x,
#    2004     batch_size=batch_size,
#    2005     steps_per_epoch=steps,
#    2006     initial_epoch=0,
#    2007     epochs=1,
#    2008     max_queue_size=max_queue_size,
#    2009     workers=workers,
#    2010     use_multiprocessing=use_multiprocessing,
#    2011     model=self,
#    2012     steps_per_execution=self._steps_per_execution)
#    2014 # Container that configures and calls `tf.keras.Callback`s.
#    2015 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\engine\data_adapter.py:1401, in get_data_handler(*args, **kwargs)
#    1399 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1400   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1401 return DataHandler(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\engine\data_adapter.py:1151, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1148   self._steps_per_execution = steps_per_execution
#    1150 adapter_cls = select_data_adapter(x, y)
# -> 1151 self._adapter = adapter_cls(
#    1152     x,
#    1153     y,
#    1154     batch_size=batch_size,
#    1155     steps=steps_per_epoch,
#    1156     epochs=epochs - initial_epoch,
#    1157     sample_weights=sample_weight,
#    1158     shuffle=shuffle,
#    1159     max_queue_size=max_queue_size,
#    1160     workers=workers,
#    1161     use_multiprocessing=use_multiprocessing,
#    1162     distribution_strategy=tf.distribute.get_strategy(),
#    1163     model=model)
#    1165 strategy = tf.distribute.get_strategy()
#    1167 self._current_step = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\engine\data_adapter.py:292, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     286   return indices
#     288 # We prefetch a single element. Computing large permutations can take quite
#     289 # a while so we don't want to wait for prefetching over an epoch boundary to
#     290 # trigger the next permutation. On the other hand, too many simultaneous
#     291 # shuffles can contend on a hardware level and degrade all performance.
# --> 292 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     294 def slice_batch_indices(indices):
#     295   """Convert a Tensor of indices into a dataset of batched indices.
#     296
#     297   This step can be accomplished in several ways. The most natural is to
#    (...)
#     308     A Dataset of batched indices.
#     309   """
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\data\ops\dataset_ops.py:1321, in DatasetV2.prefetch(self, buffer_size, name)
#    1319 if DEBUG_MODE:
#    1320   return self
# -> 1321 return PrefetchDataset(self, buffer_size, name=name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\data\ops\dataset_ops.py:5518, in PrefetchDataset.__init__(self, input_dataset, buffer_size, slack_period, name)
#    5514 # pylint: disable=protected-access
#    5515 # We colocate the prefetch dataset with its input as this collocation only
#    5516 # happens automatically in graph mode.
#    5517 with ops.colocate_with(input_dataset._variant_tensor):
# -> 5518   variant_tensor = gen_dataset_ops.prefetch_dataset(
#    5519       input_dataset._variant_tensor,
#    5520       buffer_size=self._buffer_size,
#    5521       slack_period=slack_period,
#    5522       **self._common_args)
#    5523 super(PrefetchDataset, self).__init__(input_dataset, variant_tensor)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\ops\gen_dataset_ops.py:6159, in prefetch_dataset(input_dataset, buffer_size, output_types, output_shapes, slack_period, legacy_autotune, buffer_size_min, metadata, name)
#    6157 if tld.is_eager:
#    6158   try:
# -> 6159     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6160       _ctx, "PrefetchDataset", name, input_dataset, buffer_size,
#    6161       "output_types", output_types, "output_shapes", output_shapes,
#    6162       "slack_period", slack_period, "legacy_autotune", legacy_autotune,
#    6163       "buffer_size_min", buffer_size_min, "metadata", metadata)
#    6164     return _result
#    6165   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
